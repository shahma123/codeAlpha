# %% [markdown]
# <a href="https://colab.research.google.com/github/shahma123/codeAlpha/blob/main/code_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
from flask import Flask, request

app = Flask(__name__)

@app.route("/user")
def get_user():
    username = request.args.get('username')
    # VULNERABILITY: SQL Injection
    query = "SELECT * FROM users WHERE username = '" + username + "'"

    # VULNERABILITY: Insecure direct object reference / No Auth
    conn = sqlite3.connect('users.db')
    return conn.execute(query).fetchall()

# %%
# !pip install bandit
# Save the vulnerable code to a file
with open("app.py", "w") as f:
    f.write("import os\nos.system(input())") # Example of a Command Injection risk

# Run the auditor
# !bandit -r app.py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.4/134.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.0 MB/s eta 0:00:00
# ...
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.12.12
# Run started:2026-01-13 04:08:01.303632+00:00
#
# Test results:
# >> Issue: [B605:start_process_with_a_shell] Starting a process with a shell, possible injection detected, security issue.
#    Severity: High   Confidence: High
#    CWE: CWE-78 (https://cwe.mitre.org/data/definitions/78.html)
#    More Info: https://bandit.readthedocs.io/en/1.9.2/plugins/b605_start_process_with_a_shell.html
#    Location: ./app.py:2:0
# 1	import os
# 2	os.system(input())
#
# --------------------------------------------------
#
# Code scanned:
# 	Total lines of code: 2
# 	Total lines skipped (#nosec): 0
#
# Run metrics:
# ...
